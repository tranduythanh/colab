# %% [markdown]
# <a href="https://colab.research.google.com/github/tranduythanh/colab/blob/main/svd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt

def lengthVec(vec):
  print(vec[0,:]**2+vec[1,:]**2)

def drawVec(vec, color):
  plt.figure(figsize=(2,2), dpi=100)
  origin = np.array([[0, 0], [0, 0]])
  plt.quiver(*origin, vec[0, :], vec[1, :], color=[color, color,], scale=20, width=0.005)
  plt.quiver(*origin, vec[0, :], vec[1, :], color=[color, color,], scale=20, width=0.005)
  plt.xlim(-10,10)
  plt.ylim(-10,10)
  plt.grid(color='black', linestyle='-', linewidth=0.1)
  plt.xticks(np.arange(-10, 10, 1))
  plt.yticks(np.arange(-10, 10, 1))
  plt.show()

# fig, axs = plt.subplots(6)

# define vector set
vec = np.array([[0, 1], [2, 0]])
drawVec(vec, 'black')
lengthVec(vec)

# define a matrix
A = np.array([[1, -1], [1, 2]])

# SVD
U, S, VT = np.linalg.svd(A)
S = np.diag(S)
print(S)
V = VT.T

drawVec(V, 'green')
drawVec(VT@vec, 'red')
print(VT)
print(vec)
print(VT@vec)
lengthVec(VT@vec)
drawVec(S@VT@vec, 'red')
drawVec(U, 'green')
drawVec(A@vec, 'blue')
# Out:
# [4 1]
# [[2.30277564 0.        ]
#  [0.         1.30277564]]
# [[ 0.28978415  0.95709203]
#  [ 0.95709203 -0.28978415]]
# [[0 1]
#  [2 0]]
# [[ 1.91418405  0.28978415]
#  [-0.5795683   0.95709203]]
# [4. 1.]
